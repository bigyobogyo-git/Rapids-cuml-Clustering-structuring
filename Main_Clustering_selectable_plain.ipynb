# %%
# !pip install ipynb

import torch
import gc
import time

class Main():
    def __init__(self, clustering_type: str, plotting_type: str, *args):
        self.clustering_type = clustering_type
        self.plotting_type = plotting_type
        self.args = args

    def Empty_cache(self):
        torch.cuda.empty_cache()
        gc.collect()

    def Clustering(self):
        
        if ((self.clustering_type == 'KMEANS' or self.clustering_type == 'kmeans') and (self.plotting_type == 'matplotlib')):
            from ipynb.fs.full.KMEANS_to_import_matplotlib import Clustering
            clust_matplotlib = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5],
                self.args[6], self.args[7], self.args[8], self.args[9], self.args[10])
            clust_matplotlib.main()
        elif ((self.clustering_type == 'KMEANS' or self.clustering_type == 'kmeans')) and (self.plotting_type == 'seaborn'):
            from ipynb.fs.full.KMEANS_to_import_seaborn import Clustering
            clust_seaborn = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5],
                self.args[6], self.args[7], self.args[8], self.args[9], self.args[10])
            clust_seaborn.main()
        elif (self.clustering_type == 'DBSCAN' or self.clustering_type == 'dbscan') and (self.plotting_type == 'matplotlib'):
            from ipynb.fs.full.DBSCAN_to_import_matplotlib import Clustering
            clust_matplotlib = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5],
                self.args[6], self.args[7], self.args[8], self.args[9])
            clust_matplotlib.main()
        elif (self.clustering_type == 'DBSCAN' or self.clustering_type == 'dbscan') and (self.plotting_type == 'seaborn'):
            from ipynb.fs.full.DBSCAN_to_import_matplotlib import Clustering
            clust_seaborn = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5],
                self.args[6], self.args[7], self.args[8], self.args[9])
            clust_seaborn.main()
        elif (self.clustering_type == 'HDBSCAN' or self.clustering_type == 'hdbscan') and (self.plotting_type == 'matplotlib'):
            from ipynb.fs.full.HDBSCAN_to_import_matplotlib import Clustering
            clust_matplotlib = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5], 
                                          self.args[6], self.args[7], self.args[8], self.args[9], self.args[10], self.args[11], 
                                          self.args[12], self.args[13], self.args[14], self.args[15], self.args[16], self.args[17])
            clust_matplotlib.main()
        elif (self.clustering_type == 'HDBSCAN' or self.clustering_type == 'hdbscan') and (self.plotting_type == 'seaborn'):
            from ipynb.fs.full.HDBSCAN_to_import_seaborn import Clustering
            clust_seaborn = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5], 
                                          self.args[6], self.args[7], self.args[8], self.args[9], self.args[10], self.args[11], 
                                          self.args[12], self.args[13], self.args[14], self.args[15], self.args[16], self.args[17])
            clust_seaborn.main()
        elif (self.clustering_type == 'Spectral Clustering') and (self.plotting_type == 'matplotlib'):
            from ipynb.fs.full.DBSCAN_to_import_matplotlib import Clustering
            clust_matplotlib = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5], 
                                          self.args[6], self.args[7], self.args[8], self.args[9])
            clust_matplotlib.main()
        elif (self.clustering_type == 'Spectral Clustering') and (self.plotting_type == 'seaborn'):
            from ipynb.fs.full.DBSCAN_to_import_seaborn import Clustering
            clust_seaborn = Clustering(self.args[0], self.args[1], self.args[2], self.args[3], self.args[4], self.args[5], 
                                          self.args[6], self.args[7], self.args[8], self.args[9])
            clust_seaborn.main()
        else:
            print('Error! Check your input!')

    def main(self):
        self.Empty_cahce()
        st = time.time()
        self.Clustering()
        et = time.time()
        elapsed_time = et - st
        print('Execution time:', elapsed_time, 'seconds')
